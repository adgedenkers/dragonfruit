# %%
import dropbox
import os

# %%
dbx = dropbox.Dropbox('sl.BsN0-a18PPdbM4LrM4aOkdtPMcHqK7VfOoeYniCmfUVGybeMdd9P1N3IRtjP_B-jqssQZcUM8gW5JtKAGkMAp20XHU5lUMTzE2Ga-quKmanghfkn0MKd-U0uBzAuPCahMMPMCpy7y5JzztRfKDVQ78k')

# List files in a specific Dropbox folder
for entry in dbx.files_list_folder("/dragonfruit").entries:
    print(entry.name)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 dbx = dropbox.Dropbox('sl.BsMekhAaQSEHbgkZh_PFBiSqIhyxnY7qOx6u_eUxIEYQT1qsYMnwdXJsw1_1g-jQIbrcbeYd69iSNyGA2v7fSRsBclRm8utfGa8B11LRM-wNg5dzRlSPQccIfvd6h6hVjWnwLPZZZBu1')
#       3 # List files in a specific Dropbox folder
# ----> 4 for entry in dbx.files_list_folder("/dragonfruit").entries:
#       5     print(entry.name)
#
# File ~/_code/dev/dragonfruit/venv/lib/python3.11/site-packages/dropbox/base.py:2145, in DropboxBase.files_list_folder(self, path, recursive, include_media_info, include_deleted, include_has_explicit_shared_members, include_mounted_folders, limit, shared_link, include_property_groups, include_non_downloadable_files)
#    2071 """
#    2072 Starts returning the contents of a folder. If the result's
#    2073 ``ListFolderResult.has_more`` field is ``True``, call
#    (...)
# ...
